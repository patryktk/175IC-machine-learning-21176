# %% [markdown]
# <a href="https://colab.research.google.com/github/patryktk/175IC-machine-learning-21176/blob/main/Zad6/Zad6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.svm import SVC


iris = datasets.load_iris()
data = iris.data[:, [0, 3]]
target = iris.target

X_train,X_test,y_train,y_test = train_test_split(data,target)

svm = SVC(C=0.5, kernel='linear')
svm.fit(X_train, y_train)

plot_decision_regions(X_train, y_train, clf=svm, legend=2)

acc = svm.score(data,target)

plt.xlabel('sepal length [cm]')
plt.ylabel('petal length [cm]')
plt.title(f'SVC: train accuracy:{acc}')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning:
#
# Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.

# %%
svm = SVC(C=0.4, kernel='poly')
svm.fit(X_train, y_train)

plot_decision_regions(X_train, y_train, clf=svm, legend=2)

acc = svm.score(data,target)

plt.xlabel('sepal length [cm]')
plt.ylabel('petal length [cm]')
plt.title(f'SVC: train accuracy:{acc}')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning:
#
# Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.

# %%
svm = SVC(C=0.4, kernel='sigmoid')
svm.fit(X_train, y_train)

plot_decision_regions(X_train, y_train, clf=svm, legend=2)

acc = svm.score(data,target)

plt.xlabel('sepal length [cm]')
plt.ylabel('petal length [cm]')
plt.title(f'SVC: train accuracy:{acc}')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning:
#
# Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.

# %%
svm = SVC(C=0.2, kernel='rbf')
svm.fit(X_train, y_train)

plot_decision_regions(X_train, y_train, clf=svm, legend=2)

acc = svm.score(data,target)

plt.xlabel('sepal length [cm]')
plt.ylabel('petal length [cm]')
plt.title(f'SVC: train accuracy:{acc}')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning:
#
# Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
